# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Line chart

# %%
x = list(range(1,11))
y1,y2 = np.random.randn(10),np.random.randn(10)
#print(x,y1,y2)

plt.xlabel('Range')
plt.ylabel('Random Values')
plt.title('Line chart example')


plt.plot(x,y1)
plt.plot(x,y2)

plt.legend(['y1','y2']);

# %% [markdown]
# #### Markers : https://matplotlib.org/api/markers_api.html
#
# Styling lines and markers
# The plt.plot function supports many arguments for styling lines and markers:
#
# * color or c: set the color of the line [supported colors](https://jovian.ml/outlink?url=https%3A%2F%2Fmatplotlib.org%2F3.1.0%2Fgallery%2Fcolor%2Fnamed_colors.html)
# * linestyle or ls: choose between a solid or dashed line
# * linewidth or lw: set the width of a line
# * markersize or ms: set the size of markers
# * markeredgecolor or mec: set the edge color for markers
# * markeredgewidth or mew: set the edge width for markers
# * markerfacecolor or mfc: set the fill color for markers
# * alpha: opacity of the plot
# Check out the documentation for plt.plot to learn more: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
plt.plot(x,y1,marker='s',c='lime')
plt.plot(x,y2,marker='x')

plt.legend(['y1','y2']);

# %%
plt.plot(x, y1, marker='s', c='b', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(x, y2, marker='o', c='r', ls='--', lw=3, ms=10, alpha=.5)

# %% [markdown]
# The fmt argument provides a shorthand for specifying the line style, marker and line color. It can be provided as the third argument to plt.plot.
#
# fmt = '[marker][line][color]'

# %%
plt.plot(x, y1, marker='s', c='lime', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(x, y2, '8--r'); #mlc

plt.legend(['y1','y2']);

# %%
y3 = np.random.randn(10)
plt.plot(x, y3, 'og'); # no line, so just with marker and colour in format

# %%
tmp = {2008: 'Rajasthan Royals', 2009: 'Delhi Daredevils', 2010: 'Mumbai Indians', 2011: 'Chennai Super Kings', 2012: 'Kolkata Knight Riders', 2013: 'Mumbai Indians', 2014: 'Kings XI Punjab', 2015: 'Chennai Super Kings', 2016: 'Sunrisers Hyderabad', 2017: 'Mumbai Indians', 2018: 'Chennai Super Kings', 2019: 'Mumbai Indians'}

plt.title('Season Winners')
plt.xticks(rotation=90)
plt.xlabel('teams')
plt.ylabel('season')

plt.plot(list(tmp.values()),list(tmp.keys()),'or');

# %% [markdown]
# # Improving Default Styles using Seaborn
# An easy way to make your charts look beautiful is to use some default styles provided in the Seaborn library.
#
# These can be applied globally using the sns.set_style function. You can see a full list of predefined styles here: https://seaborn.pydata.org/generated/seaborn.set_style.html

# %%
sns.set_style('darkgrid') #darkgrid
#sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})

# %%
plt.title('Season Winners')
plt.xticks(rotation=90)
plt.xlabel('teams')
plt.ylabel('season')

plt.plot(list(tmp.values()),list(tmp.keys()),'or');

# %% [markdown]
# # Scatter plot
#
# * **line plot** is used to represent a sequence of values
# * **Scatter plot** is used to represent the relationship between  2 variables
# *  the values of 2 variables are plotted as points on a 2-dimensional grid. Additionally, you can also use a third variable to determine the size or color of the points. Let's try out an example.

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Scatter plot directly from pandas dataframe

# %%
plt.title('Scatter plot sepal len and width w.r.t species type')

sns.scatterplot('sepal_length',
           'sepal_width',
            hue = 'species',
            s = 100,
            data = df
           );

# %% [markdown]
# # line plot vs scatter plot

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))

fig,ax
# Out:
# (<Figure size 720x360 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000022A7D55ED08>,
# ...
#        dtype=object))

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax[0].plot(df.sepal_length,df.sepal_width)
ax[0].plot(df.petal_length,df.petal_width)


ax[1].set_title('sepal len & width plot 2-var comp w.r.t type')
sns.scatterplot(df.sepal_length,
                df.sepal_width,
                hue = df.species,
                s = 50
               );
#sns.scatterplot(df.petal_length,df.petal_width);

# %% [markdown]
# # Histogram
# A histogram represents **the distribution of data by forming bins along the range of the data** and then **drawing bars** to show the number of observations that fall in each bin.
#
# As an example, let's visualize the how the values of sepal width in the flowers dataset are distributed. We can use the plt.hist function to create a histogram.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# * here min value of sepal_width is "2.0" and max value is "4.4".
# * If we want to know the the distribution in between 2.5 to 3.5, then this histogram is much needed

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.title('Distribution of sepal_width')
plt.ylabel('Count having "sepal_width" values')
plt.xlabel('sepal_width value')
plt.hist(df.sepal_width);

# %% [markdown]
# * Here each interval is called as **"bins"**
# * Bydefault in above bins are 10... this can be changed with *arg : bins
# * **Explanation :**
#     sepal_width = 3.0 has more than > 35

# %%
plt.hist(df.sepal_width,bins=5);

# %%
np.arange(2,6,1)
# Out:
# array([2, 3, 4, 5])

# %%
plt.hist(df.sepal_width,bins=np.arange(2,5,0.25));

# %% [markdown]
# # Multiple histograms

# %%
s_df = df[df.species=='setosa']
ve_df = df[df.species=='versicolor']
vi_df = df[df.species=='virginica']


plt.title('Multi Histogram')

plt.hist(s_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25))
plt.hist(ve_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25))
plt.hist(vi_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25));

#plt.legend(df.species.unique())
plt.legend(['setosa', 'versicolor', 'virginica'])

# %% [markdown]
# **here its overlapping.**
# we can also do **stack multiple histograms** on top of one another

# %%
plt.hist([s_df.sepal_width,ve_df.sepal_width,vi_df.sepal_width], alpha =0.6,bins=np.arange(2,5,0.25),stacked=False)
plt.legend(df.species.unique());

# %%
plt.hist([s_df.sepal_width,ve_df.sepal_width,vi_df.sepal_width], alpha =0.6,bins=np.arange(2,5,0.25),stacked=True)
plt.legend(df.species.unique());

# %% [markdown]
# # Bar Chart
# Bar charts are quite similar to line charts i.e. they show a sequence of values, however a bar is shown for each value, rather than points connected by lines. We can use the plt.bar function to draw a bar chart.

# %%
years = list(range(2000, 2006))
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))

ax[0].set_xlabel('years')
ax[0].set_ylabel('Crop values')
ax[0].plot(years,apples)
ax[0].plot(years,oranges)
ax[0].set_title('Apples vs Oranges Line chart')
ax[0].legend(['Apples','oranges']);


ax[1].set_xlabel('years')
ax[1].set_ylabel('Crop values')
ax[1].bar(years,apples)
ax[1].bar(years,oranges)
ax[1].set_title('Apples vs Oranges Line chart')
ax[1].legend(['Apples','oranges']);

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))

ax[0].set_xlabel('years')
ax[0].set_ylabel('Crop values')
ax[0].plot(years,apples)
#ax[0].plot(years,oranges)
ax[0].set_title('Apples vs Oranges Line chart')
ax[0].legend(['Apples','oranges']);


ax[1].set_xlabel('years')
ax[1].set_ylabel('Crop values')
ax[1].bar(years,apples)
ax[1].plot(years,apples,'o--r')
ax[1].set_title('Apples vs Oranges Line chart')
ax[1].legend(['Apples']);

# %% [markdown]
# Like histograms, bars can also be stacked on top of one another. We use the bottom argument to plt.bar to achieve this.

# %%
plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples)
plt.plot(years, apples,'o--r')
plt.plot(years, oranges,'o--g')
plt.legend(['Apples','oranges']);

# %% [markdown]
# # Bar plot with averages

# %%
t_df = sns.load_dataset('tips')
t_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Q: Now, lets plot the bar plot for average bill over day??

# %%
avgBill_df = t_df.groupby(['day'])[['total_bill']].mean()
avgBill_df
# Out:
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(avgBill_df.index,avgBill_df.total_bill);

# %%
sns.barplot(avgBill_df.index,avgBill_df.total_bill);

# %%
sns.barplot('day','total_bill',data=t_df);

# %%
sns.barplot('day','total_bill',hue='sex',data=t_df);

# %% [markdown]
# # Heatmap:
# A heatmap is used to visualize 2-dimensional data like a matrix or a table using colors. The best way to understand it is by looking at an example. We'll use another sample dataset from Seaborn, called "flights", to visualize monthly passenger footfall at an airport over 12 years.

# %%
df = sns.load_dataset('flights')
df
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
plt.plot(df.passengers);

# %%
df_hm = df.pivot('month','year','passengers')
df_hm
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
plt.title('No. of passengers in 1000\'s')
sns.heatmap(df_hm);

# %% [markdown]
# The brighter colors indicate a higher footfall at the airport. By looking at the graph, we can infer two things:
#
# The footfall at the airport in any given year tends to be the highest around July & August.
# The footfall at the airport in any given month tends to grow year by year.
# We can also display the actual values in each block by specifying annot=True, and use the cmap argument to change the color palette.

# %%
plt.title('No. of passengers in 1000\'s')

sns.heatmap(df_hm,fmt="d",annot=True);

# %%
plt.title('No. of passengers in 1000\'s')

sns.heatmap(df_hm,fmt="d",annot=True,cmap='Blues');

# %%
np_a = np.random.randn(3,20,20)

# %%
sns.heatmap(np_a[0][:],fmt='f');
sns.heatmap(np_a[1][:],fmt='f');
#sns.heatmap(np_a[2][:],fmt='f');

# %% [markdown]
# # Image plot

# %%
from PIL import Image
im = Image.open('test.jpg')
im_np = np.array(im)
print(im_np.shape)
# Out:
# (256, 256, 3)

# %%
plt.imshow(im);

# %%
plt.grid(False)
plt.imshow(im);

# %%
print(im_np[100:200,50:150].shape)
plt.imshow(im_np[100:200,50:150]);
# Out:
# (100, 100, 3)

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(im);

# %% [markdown]
# # Plotting multiple charts in a grid
# Matplotlib and Seaborn also support plotting multiple charts in a grid, using plt.subplots, which returns a set of axes that can be used for plotting.
#
# Here's a single grid showing the different types of charts we've covered in this tutorial.

# %%
t_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
flowers_df = sns.load_dataset('iris')
setosa_df  = flowers_df[flowers_df.species=='setosa'] 
versicolor_df = flowers_df[flowers_df.species=='versicolor'] 
virginica_df = flowers_df[flowers_df.species=='virginica'] 

flights_df = sns.load_dataset('flights')

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 8))

# Use the axes for plotting
axes[0,0].plot(years, apples, 's-b')
axes[0,0].plot(years, oranges, 'o--r')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Yield (tons per hectare)')
axes[0,0].legend(['Apples', 'Oranges']);
axes[0,0].set_title('Crop Yields in Kanto')


# Pass the axes into seaborn
axes[0,1].set_title('Sepal Length vs. Sepal Width')
sns.scatterplot(flowers_df.sepal_length, 
                flowers_df.sepal_width, 
                hue=flowers_df.species, 
                s=100, 
                ax=axes[0,1]);

# Use the axes for plotting
axes[0,2].set_title('Distribution of Sepal Width')
axes[0,2].hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

axes[0,2].legend(['Setosa', 'Versicolor', 'Virginica']);

# Pass the axes into seaborn
axes[1,0].set_title('Restaurant bills')
sns.barplot('day', 'total_bill', hue='sex', data=t_df, ax=axes[1,0]);

# Pass the axes into seaborn
axes[1,1].set_title('Flight traffic')
df = flights_df.pivot('month','year','passengers')
sns.heatmap(df, fmt='d',cmap='Blues', annot=True,ax=axes[1,1]);


# Plot an image using the axes
axes[1,2].set_title('Data Science Meme')
axes[1,2].imshow(im)
axes[1,2].grid(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])

plt.tight_layout(pad=2);

# %% [markdown]
# See this page for a full list of supported functions: https://matplotlib.org/3.3.1/api/axes_api.html#the-axes-class.

# %% [markdown]
# # Pair plots with Seaborn
# Seaborn also provides a helper function sns.pairplot to automatically plot different types of charts for pairs of features within a dataframe.

# %%
sns.pairplot(flowers_df, hue='species');

# %%
sns.pairplot(t_df, hue='sex');

# %% [markdown]
# # References and Further Reading
# In this tutorial we've covered some of the fundamental concepts and popular techniques for data visualization using Matplotlib and Seaborn. Data visualization is a vast field and we've barely scratched the surface here. Check out these references to learn and discover more:
#
# * Data Visualization cheat sheet: https://jovian.ml/aakashns/dataviz-cheatsheet
# * Seaborn gallery: https://seaborn.pydata.org/examples/index.html
# * Matplotlib gallery: https://matplotlib.org/3.1.1/gallery/index.html
# * Matplotlib tutorial: https://github.com/rougier/matplotlib-tutorial
# * As a next step, you can try working on a data analysis project: https://jovian.ml/aakashns/zerotopandas-course-project-starter
